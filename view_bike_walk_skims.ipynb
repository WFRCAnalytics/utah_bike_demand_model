# %%
import pandas as pd
import pyarrow.parquet as pq

# Read the parquet file
skims = pd.read_parquet("Model_Outputs/NonMotorizedSkims/bike_skims.parquet")

# Display the shape
print(f"Shape: {skims.shape}")
print(f"\nMatrix headers (columns):")
print(skims.columns.tolist())

# Display first few rows to see data structure
print(f"\nFirst few rows:")
skims
# Out:
# Shape: (75030432, 8)
#
# Matrix headers (columns):
# ['orig_zone', 'dest_zone', 'bike_commute_cost', 'bike_commute_distance', 'bike_commute_time', 'bike_noncommute_cost', 'bike_noncommute_distance', 'bike_noncommute_time']
#
# First few rows:
#           orig_zone  dest_zone  bike_commute_cost  bike_commute_distance  \
# 0               0.0        1.0          12.105750               6.111848
# 1               0.0        2.0          15.028669               7.965358
# 2               0.0        3.0           6.436137               5.396276
# 3               0.0        4.0          12.257289               5.169545
# 4               0.0        5.0          15.971394               7.057765
# ...             ...        ...                ...                    ...
# 75030427    24530.0    24525.0          17.463963               9.912300
# 75030428    24530.0    24526.0           6.337572               3.773758
# 75030429    24530.0    24527.0          16.892986               9.468347
# ...

# %%
import pandas as pd
import pyarrow.parquet as pq

# Read the parquet file
skims = pd.read_parquet("Model_Outputs/NonMotorizedSkims/walk_skims.parquet")

# Display the shape
print(f"Shape: {skims.shape}")
print(f"\nMatrix headers (columns):")
print(skims.columns.tolist())

# Display first few rows to see data structure
print(f"\nFirst few rows:")
skims
# Out:
# Shape: (22258690, 5)
#
# Matrix headers (columns):
# ['orig_zone', 'dest_zone', 'walk_cost', 'walk_distance', 'walk_time']
#
# First few rows:
#           orig_zone  dest_zone  walk_cost  walk_distance   walk_time
# 0               0.0        1.0   8.446678       5.786901  112.004532
# 1               0.0        4.0   6.993254       4.771932   92.359352
# 2               0.0       52.0   1.581554       1.447730   28.020590
# 3               0.0    11823.0   7.127605       5.347101  110.319679
# 4               0.0    11877.0   7.037331       5.280688  112.097847
# ...             ...        ...        ...            ...         ...
# 22258685    24530.0    22675.0   2.426406       2.060577   39.882133
# 22258686    24530.0    22691.0   1.687041       1.561212   30.217009
# 22258687    24530.0    22713.0   1.140139       1.054309   20.405991
# 22258688    24530.0    22716.0   1.845570       1.699740   32.898197
# 22258689    24530.0    23237.0   2.807274       2.647274   51.237568
#
# ...
